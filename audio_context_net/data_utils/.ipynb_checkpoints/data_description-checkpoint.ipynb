# %%
import numpy as np
import pandas as pd

# %%
example_counts = pd.read_csv("mimii_example_counts.csv")
example_counts = example_counts.drop("Unnamed: 0", axis=1)
example_counts
# Out:
#    machine type machine id     SNR   train    val    test
# 0           fan      id_00     0dB  186636  18540  251526
# 1           fan      id_02     0dB  203013  20394  221862
# 2           fan      id_04     0dB  211665  21012  215064
# 3           fan      id_06     0dB  202086  20085  223098
# 4          pump      id_00     0dB  266667  26574   88374
# 5          pump      id_02     0dB  276246  27501   68598
# 6          pump      id_04     0dB  186018  18540   61800
# 7          pump      id_06     0dB  288606  28737   63036
# 8        slider      id_00     0dB  220008  21939  220008
# 9        slider      id_02     0dB  247509  24720  165006
# 10       slider      id_04     0dB  110004  11124  110004
# 11       slider      id_06     0dB  137505  13596   55002
# 12        valve      id_00     0dB  269448  26883   73542
# 13        valve      id_02     0dB  181692  18231   74160
# 14        valve      id_04     0dB  271920  27192   74160
# ...

# %%
file_counts = pd.read_csv("mimii_file_counts.csv")
file_counts = file_counts.drop("Unnamed: 0", axis=1)
file_counts
# Out:
#    machine type machine id     SNR  train  val  test total  test normal  \
# 0           fan      id_00     0dB    604   60         814          407
# 1           fan      id_02     0dB    657   66         718          359
# 2           fan      id_04     0dB    685   68         696          348
# 3           fan      id_06     0dB    654   65         722          361
# 4          pump      id_00     0dB    863   86         286          143
# 5          pump      id_02     0dB    894   89         222          111
# 6          pump      id_04     0dB    602   60         200          100
# 7          pump      id_06     0dB    934   93         204          102
# 8        slider      id_00     0dB    712   71         712          356
# 9        slider      id_02     0dB    801   80         534          267
# 10       slider      id_04     0dB    356   36         356          178
# 11       slider      id_06     0dB    445   44         178           89
# ...

# %%
print(example_counts.to_latex(index=False))
# Out:
# \begin{tabular}{lllrrr}
# \toprule
# machine type & machine id &     SNR &   train &    val &    test \\
# \midrule
#          fan &      id\_00 &     0dB &  186636 &  18540 &  251526 \\
#          fan &      id\_02 &     0dB &  203013 &  20394 &  221862 \\
#          fan &      id\_04 &     0dB &  211665 &  21012 &  215064 \\
#          fan &      id\_06 &     0dB &  202086 &  20085 &  223098 \\
#         pump &      id\_00 &     0dB &  266667 &  26574 &   88374 \\
#         pump &      id\_02 &     0dB &  276246 &  27501 &   68598 \\
#         pump &      id\_04 &     0dB &  186018 &  18540 &   61800 \\
#         pump &      id\_06 &     0dB &  288606 &  28737 &   63036 \\
#       slider &      id\_00 &     0dB &  220008 &  21939 &  220008 \\
#       slider &      id\_02 &     0dB &  247509 &  24720 &  165006 \\
#       slider &      id\_04 &     0dB &  110004 &  11124 &  110004 \\
#       slider &      id\_06 &     0dB &  137505 &  13596 &   55002 \\
# ...

# %%
print(file_counts.to_latex(index=False))
# Out:
# \begin{tabular}{lllrrrrr}
# \toprule
# machine type & machine id &     SNR &  train &  val &  test total &  test normal &  test abnormal \\
# \midrule
#          fan &      id\_00 &     0dB &    604 &   60 &         814 &          407 &            407 \\
#          fan &      id\_02 &     0dB &    657 &   66 &         718 &          359 &            359 \\
#          fan &      id\_04 &     0dB &    685 &   68 &         696 &          348 &            348 \\
#          fan &      id\_06 &     0dB &    654 &   65 &         722 &          361 &            361 \\
#         pump &      id\_00 &     0dB &    863 &   86 &         286 &          143 &            143 \\
#         pump &      id\_02 &     0dB &    894 &   89 &         222 &          111 &            111 \\
#         pump &      id\_04 &     0dB &    602 &   60 &         200 &          100 &            100 \\
#         pump &      id\_06 &     0dB &    934 &   93 &         204 &          102 &            102 \\
# ...
